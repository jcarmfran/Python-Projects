# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import datetime

# %%
df = pd.read_csv('Spreadsheets/box_score_all.csv')

# %%
print('Total number of rows in the dataset = {}'.format(df.shape[0]))
print('Total number of columns in the dataset = {}'.format(df.shape[1]))
# Out:
# Total number of rows in the dataset = 2460
# Total number of columns in the dataset = 64

# %%
df.head()
# Out:
#                         Date  assists  assistsTurnoverRatio  benchPoints  \
# 0  2022-10-18T19:30:00-04:00     16.0              1.142857         11.0
# 1  2022-10-18T19:30:00-04:00     24.0              2.181818         34.0
# 2  2022-10-18T22:00:00-04:00     23.0              1.045455         24.0
# 3  2022-10-18T22:00:00-04:00     31.0              1.722222         41.0
# 4  2022-10-19T19:00:00-04:00     21.0              1.166667         17.0
#
#    biggestLead biggestLeadScore  biggestScoringRun biggestScoringRunScore  \
# 0          8.0            25-17               10.0                  25-17
# 1         16.0          110-126               10.0                  25-17
# 2          2.0              2-0               11.0                  64-89
# 3         27.0            64-91               13.0                  64-91
# 4         15.0             21-6               19.0                   21-6
#
#    blocks  blocksReceived  ...  trueShootingAttempts  trueShootingPercentage  \
# 0     3.0             3.0  ...                 92.32                0.633666
# 1     3.0             3.0  ...                 94.32                0.667939
# 2     4.0             3.0  ...                104.00                0.524038
# 3     3.0             4.0  ...                109.12                0.563600
# 4     5.0             4.0  ...                 94.36                0.577575
#
#    turnovers  turnoversTeam  turnoversTotal  twoPointersAttempted  \
# 0       14.0            0.0            14.0                  46.0
# 1       10.0            1.0            11.0                  47.0
# 2       21.0            1.0            22.0                  53.0
# 3       18.0            0.0            18.0                  54.0
# 4       18.0            0.0            18.0                  56.0
#
#    twoPointersMade  twoPointersPercentage  Home/Away   Game ID
# 0             27.0               0.586957       Away  22200001
# 1             34.0               0.723404       Home  22200001
# 2             30.0               0.566038       Away  22200002
# 3             29.0               0.537037       Home  22200002
# 4             31.0               0.553571       Away  22200003
#
# [5 rows x 64 columns]

# %% [markdown]
# ### Reformatting Datetime

# %%
dates = df["Date"].str.slice(stop=10)

# %%
print(type(dates))
# Out:
# <class 'pandas.core.series.Series'>

# %%
dates = pd.to_datetime(dates, format='%Y-%m-%d')

# %%
dates
# Out:
# 0      2022-10-18
# 1      2022-10-18
# 2      2022-10-18
# 3      2022-10-18
# 4      2022-10-19
#           ...
# 2455   2023-04-09
# 2456   2023-04-09
# 2457   2023-04-09
# 2458   2023-04-09
# 2459   2023-04-09
# Name: Date, Length: 2460, dtype: datetime64[ns]

# %%
df['Date']
# Out:
# 0       2022-10-18T19:30:00-04:00
# 1       2022-10-18T19:30:00-04:00
# 2       2022-10-18T22:00:00-04:00
# 3       2022-10-18T22:00:00-04:00
# 4       2022-10-19T19:00:00-04:00
#                   ...
# 2455    2023-04-09T15:30:00-04:00
# 2456    2023-04-09T15:30:00-04:00
# 2457    2023-04-09T15:30:00-04:00
# 2458    2023-04-09T15:30:00-04:00
# 2459    2023-04-09T15:30:00-04:00
# Name: Date, Length: 2460, dtype: object

# %%
df['DatesF'] = dates

# %%
df['DatesF']
# Out:
# 0      2022-10-18
# 1      2022-10-18
# 2      2022-10-18
# 3      2022-10-18
# 4      2022-10-19
#           ...
# 2455   2023-04-09
# 2456   2023-04-09
# 2457   2023-04-09
# 2458   2023-04-09
# 2459   2023-04-09
# Name: DatesF, Length: 2460, dtype: datetime64[ns]

# %% [markdown]
# ### Multilevel Dataframe

# %%
multi_df = df.set_index(['DatesF', 'Game ID'])

# %%
multi_df
# Out:
#                                           Date  assists  assistsTurnoverRatio  \
# DatesF     Game ID
# 2022-10-18 22200001  2022-10-18T19:30:00-04:00     16.0              1.142857
#            22200001  2022-10-18T19:30:00-04:00     24.0              2.181818
#            22200002  2022-10-18T22:00:00-04:00     23.0              1.045455
#            22200002  2022-10-18T22:00:00-04:00     31.0              1.722222
# 2022-10-19 22200003  2022-10-19T19:00:00-04:00     21.0              1.166667
# ...                                        ...      ...                   ...
# 2023-04-09 22201228  2023-04-09T15:30:00-04:00     28.0              2.545455
#            22201229  2023-04-09T15:30:00-04:00     22.0              2.200000
#            22201229  2023-04-09T15:30:00-04:00     29.0              4.142857
#            22201230  2023-04-09T15:30:00-04:00     47.0              2.937500
#            22201230  2023-04-09T15:30:00-04:00     25.0              1.785714
#
#                      benchPoints  biggestLead biggestLeadScore  \
# DatesF     Game ID
# 2022-10-18 22200001         11.0          8.0            25-17
#            22200001         34.0         16.0          110-126
#            22200002         24.0          2.0              2-0
#            22200002         41.0         27.0            64-91
# 2022-10-19 22200003         17.0         15.0             21-6
# ...                          ...          ...              ...
# 2023-04-09 22201228         35.0         14.0            63-77
#            22201229         53.0          6.0            59-53
#            22201229         40.0         11.0            17-28
#            22201230         88.0         59.0           150-91
#            22201230         21.0          0.0           150-91
#
#                      biggestScoringRun biggestScoringRunScore  blocks  \
# DatesF     Game ID
# 2022-10-18 22200001               10.0                  25-17     3.0
#            22200001               10.0                  25-17     3.0
#            22200002               11.0                  64-89     4.0
#            22200002               13.0                  64-91     3.0
# 2022-10-19 22200003               19.0                   21-6     5.0
# ...                                ...                    ...     ...
# 2023-04-09 22201228               13.0                   3-13     7.0
#            22201229               14.0                  59-53     5.0
#            22201229               14.0                  59-53     3.0
#            22201230               14.0                  46-23     6.0
#            22201230               12.0                  44-23     3.0
#
#                      blocksReceived  ...  timesTied  trueShootingAttempts  \
# DatesF     Game ID                   ...
# 2022-10-18 22200001             3.0  ...        7.0                 92.32
#            22200001             3.0  ...        7.0                 94.32
#            22200002             3.0  ...        2.0                104.00
#            22200002             4.0  ...        2.0                109.12
# 2022-10-19 22200003             4.0  ...        4.0                 94.36
# ...                             ...  ...        ...                   ...
# 2023-04-09 22201228             4.0  ...        0.0                106.24
#            22201229             3.0  ...        8.0                110.56
#            22201229             5.0  ...        8.0                108.68
#            22201230             3.0  ...        0.0                103.04
#            22201230             6.0  ...        0.0                105.56
#
#                      trueShootingPercentage  turnovers  turnoversTeam  \
# DatesF     Game ID
# 2022-10-18 22200001                0.633666       14.0            0.0
#            22200001                0.667939       10.0            1.0
#            22200002                0.524038       21.0            1.0
#            22200002                0.563600       18.0            0.0
# 2022-10-19 22200003                0.577575       18.0            0.0
# ...                                     ...        ...            ...
# 2023-04-09 22201228                0.602410       10.0            1.0
#            22201229                0.538169       10.0            0.0
#            22201229                0.524476        7.0            0.0
#            22201230                0.761840       15.0            1.0
#            22201230                0.478401       14.0            0.0
#
#                      turnoversTotal  twoPointersAttempted  twoPointersMade  \
# DatesF     Game ID
# 2022-10-18 22200001            14.0                  46.0             27.0
#            22200001            11.0                  47.0             34.0
#            22200002            22.0                  53.0             30.0
#            22200002            18.0                  54.0             29.0
# 2022-10-19 22200003            18.0                  56.0             31.0
# ...                             ...                   ...              ...
# 2023-04-09 22201228            11.0                  52.0             29.0
#            22201229            10.0                  77.0             44.0
#            22201229             7.0                  62.0             28.0
#            22201230            16.0                  47.0             31.0
#            22201230            14.0                  60.0             29.0
#
#                      twoPointersPercentage  Home/Away
# DatesF     Game ID
# 2022-10-18 22200001               0.586957       Away
#            22200001               0.723404       Home
#            22200002               0.566038       Away
#            22200002               0.537037       Home
# 2022-10-19 22200003               0.553571       Away
# ...                                    ...        ...
# 2023-04-09 22201228               0.557692       Home
#            22201229               0.571429       Away
#            22201229               0.451613       Home
#            22201230               0.659574       Away
#            22201230               0.483333       Home
#
# [2460 rows x 63 columns]

# %% [markdown]
# ## Calculating three-point

# %%
multi_df.loc['2022-10-18']['threePointersMade']
# Out:
# Game ID
# 22200001    13.0
# 22200001    12.0
# 22200002    10.0
# 22200002    16.0
# Name: threePointersMade, dtype: float64

# %%
multi_df.loc['2022-10-18']['threePointersAttempted']
# Out:
# Game ID
# 22200001    34.0
# 22200001    35.0
# 22200002    40.0
# 22200002    45.0
# Name: threePointersAttempted, dtype: float64

# %%
# test calculation for first day's percentage of three points 
day1_attempts = multi_df.loc['2022-10-18']['threePointersAttempted'].sum()
day1_makes = multi_df.loc['2022-10-18']['threePointersMade'].sum()
day1_percentage = day1_makes/day1_attempts
print(day1_percentage)
# Out:
# 0.33116883116883117

# %%
# calculate all daily 3PT% of 2022-23 season
# list to hold daily 3PT% averages
daily_3PtP = []
# iterate through each game of season to collect 3PA and 3PM using unique date values in 'dates' series
# calculate the daily 3P% and append to global list
for d in dates.unique():
    daily_3PtM = multi_df.loc[d]['threePointersMade'].sum()
    daily_3PtA = multi_df.loc[d]['threePointersAttempted'].sum()
    daily_3PtP.append(daily_3PtM/daily_3PtA)

# %%
daily_3PtP
# Out:
# [0.33116883116883117,
#  0.34577114427860695,
#  0.2571428571428571,
#  0.37534246575342467,
#  0.40822784810126583,
#  0.3156779661016949,
#  0.34767025089605735,
#  0.30952380952380953,
#  0.36755952380952384,
#  0.3853820598006645,
#  0.35233160621761656,
#  0.3770833333333333,
#  0.35517241379310344,
#  0.34549356223175964,
#  0.36860068259385664,
#  0.33467202141900937,
#  0.42105263157894735,
#  0.36125,
#  0.3813084112149533,
#  0.2872727272727273,
#  0.3689892051030422,
#  0.34782608695652173,
#  0.32592592592592595,
#  0.3413284132841328,
#  0.35929203539823007,
#  0.38620689655172413,
#  0.33832976445396146,
#  0.38968481375358166,
#  0.3776824034334764,
#  0.3516483516483517,
#  0.3412384716732543,
#  0.3561643835616438,
#  0.35765124555160144,
#  0.33035714285714285,
#  0.3403361344537815,
#  0.3724304715840387,
#  0.33263157894736844,
#  0.3754646840148699,
#  0.3446601941747573,
#  0.3591654247391952,
#  0.3744493392070485,
#  0.35023584905660377,
#  0.41975308641975306,
#  0.36522911051212936,
#  0.3490364025695932,
#  0.33648393194706994,
#  0.3583617747440273,
#  0.35294117647058826,
#  0.3455978975032852,
#  0.39408866995073893,
#  0.3655274888558692,
#  0.37749546279491836,
#  0.32603938730853393,
#  0.3389830508474576,
#  0.3282442748091603,
#  0.3830703012912482,
#  0.33223684210526316,
#  0.36642335766423356,
#  0.3431952662721893,
#  0.3721881390593047,
#  0.38338658146964855,
#  0.37537537537537535,
#  0.3684913217623498,
#  0.3813559322033898,
#  0.3662551440329218,
#  0.3924731182795699,
#  0.3682170542635659,
#  0.33657858136300417,
#  0.35826771653543305,
#  0.3829268292682927,
#  0.3754152823920266,
#  0.3376,
#  0.3317757009345794,
#  0.35,
#  0.3273542600896861,
#  0.3413400758533502,
#  0.3193548387096774,
#  0.3925104022191401,
#  0.3617021276595745,
#  0.3777403035413153,
#  0.3960674157303371,
#  0.34765625,
#  0.3663003663003663,
#  0.3738738738738739,
#  0.3333333333333333,
#  0.3898305084745763,
#  0.3554006968641115,
#  0.38533541341653665,
#  0.3693379790940767,
#  0.3487603305785124,
#  0.41358024691358025,
#  0.3508771929824561,
#  0.4036697247706422,
#  0.36899563318777295,
#  0.4057377049180328,
#  0.3656387665198238,
#  0.3843843843843844,
#  0.34782608695652173,
#  0.3652694610778443,
#  0.37177747625508817,
#  0.35315985130111527,
#  0.37593984962406013,
#  0.33238636363636365,
#  0.36462093862815886,
#  0.32867132867132864,
#  0.3610503282275711,
#  0.3614678899082569,
#  0.38436482084690554,
#  0.33604336043360433,
#  0.3747680890538033,
#  0.34615384615384615,
#  0.3819444444444444,
#  0.3031496062992126,
#  0.353887399463807,
#  0.3130287648054145,
#  0.3825503355704698,
#  0.37787356321839083,
#  0.39204545454545453,
#  0.35294117647058826,
#  0.34615384615384615,
#  0.38176197836166925,
#  0.40066225165562913,
#  0.3179916317991632,
#  0.3626543209876543,
#  0.30677290836653387,
#  0.3440366972477064,
#  0.37738853503184716,
#  0.35815602836879434,
#  0.3586626139817629,
#  0.42780748663101603,
#  0.3658210947930574,
#  0.3945409429280397,
#  0.3682008368200837,
#  0.36682242990654207,
#  0.39896373056994816,
#  0.35656836461126007,
#  0.3383458646616541,
#  0.35555555555555557,
#  0.35239852398523985,
#  0.39080459770114945,
#  0.382089552238806,
#  0.35185185185185186,
#  0.3867403314917127,
#  0.36062378167641324,
#  0.3491686460807601,
#  0.3476190476190476,
#  0.362095531587057,
#  0.3508771929824561,
#  0.3621933621933622,
#  0.4195121951219512,
#  0.35609756097560974,
#  0.33858267716535434,
#  0.34532374100719426,
#  0.3810240963855422,
#  0.375886524822695,
#  0.35911602209944754,
#  0.38461538461538464,
#  0.3422897196261682,
#  0.3813847900113507,
#  0.3836805555555556,
#  0.35428571428571426,
#  0.3399258343634116,
#  0.40454545454545454,
#  0.3381686310063463]

# %% [markdown]
# ### Calculating two-point percentage

# %%
# calculate all daily 3PT% of 2022-23 season
# list to hold daily 3PT% averages
daily_2PtP = []
# iterate through each game of season to collect 3PA and 3PM using unique date values in 'dates' series
# calculate the daily 3P% and append to global list
for d in dates.unique():
    daily_2PtM = multi_df.loc[d]['twoPointersMade'].sum()
    daily_2PtA = multi_df.loc[d]['twoPointersAttempted'].sum()
    daily_2PtP.append(daily_2PtM/daily_2PtA)

# %% [markdown]
# ## Plotting

# %% [markdown]
# ### Two-point shooting

# %%
# specifying the rolling window size of 7 days
window_size = 7
# calculate MA using pandas.rolling().mean method
rolling_mean = pd.Series(daily_2PtP).rolling(window_size).mean()
# plot daily average of 2P%
sns.lineplot(x=dates.unique(), y=daily_2PtP)
# plot moving average of 2P%
sns.lineplot(x=dates.unique(), y=rolling_mean)
#show plot
plt.show()

# %%
# creating a new dataframe onject using daily 2P% list
daily_2ptp_df = pd.DataFrame(daily_2PtP)
# modifying name of column
daily_2ptp_df = daily_2ptp_df.rename(columns={0: 'Daily 2PtP'})

# %%
jp2 = sns.jointplot(x=(daily_2ptp_df.index + 1), y='Daily 2PtP', data=daily_2ptp_df, kind='reg')
jp2.ax_marg_x.remove()
plt.show()

# %% [markdown]
# ### Three-point shooting

# %% [markdown]
# ### Tracking 3P% Moving Average

# %% [markdown]
# 7 Day moving average

# %%
# define moving average window
window_size = 7

# calculate MA using pandas.rolling().mean method
rolling_mean = pd.Series(daily_3PtP).rolling(window_size).mean()

# plot daily average of 3P%
sns.lineplot(x=dates.unique(), y=daily_3PtP)

# plot moving average of 3P%
sns.lineplot(x=dates.unique(), y=rolling_mean)

#show plot
plt.show()

# %% [markdown]
# ### Relative Scatter Plot

# %%
sns.relplot(x=dates.unique(), y=daily_3PtP)

# %% [markdown]
# ### Regression Plot
# Parameters of a regression plot necessarily has us take a different approach when finding the regression line of these daily 3P% makes

# %%
# creating a new dataframe onject using daily 3P% list
daily_3ptp_df = pd.DataFrame(daily_3PtP)
# modifying name of column
daily_3ptp_df = daily_3ptp_df.rename(columns={0: 'Daily 3PtP'})

# %%
daily_3ptp_df
# Out:
#      Daily 3PtP
# 0      0.331169
# 1      0.345771
# 2      0.257143
# 3      0.375342
# 4      0.408228
# ..          ...
# 159    0.383681
# 160    0.354286
# 161    0.339926
# 162    0.404545
# 163    0.338169
#
# [164 rows x 1 columns]

# %%
# scatter+regression plot of daily 3P%
sns.regplot(x=(daily_3ptp_df.index + 1), y='Daily 3PtP', data=daily_3ptp_df)
# Out:
# <AxesSubplot: ylabel='Daily 3PtP'>

# %%
jp = sns.jointplot(x=(daily_3ptp_df.index + 1), y='Daily 3PtP', data=daily_3ptp_df, kind='reg')
jp.ax_marg_x.remove()
plt.show()

# %% [markdown]
# ## Are some players more deserving of the "streaky" label than others?

# %%
# kelly oubre
from nba_api.stats.endpoints import playergamelog
from nba_api.stats.library.parameters import SeasonAll

player_id = 1626162 # Kelly Oubre's player ID
season = SeasonAll.default # 2022-23 NBA season

gamelog = playergamelog.PlayerGameLog(player_id=player_id, season=season)
ko_df = gamelog.get_data_frames()[0]

three_point_pct = ko_df['FG3_PCT']

# %%
print(season)
# Out:
# 2022-23

# %%
ko_df['FG3_PCT']
# Out:
# 0     0.000
# 1     0.429
# 2     0.000
# 3     0.250
# 4     0.500
# 5     0.571
# 6     0.500
# 7     0.000
# 8     0.444
# 9     0.300
# 10    0.500
# 11    0.500
# 12    0.000
# 13    0.000
# 14    0.250
# 15    0.167
# 16    0.167
# 17    0.375
# 18    0.250
# 19    0.300
# 20    0.385
# 21    0.375
# 22    0.250
# 23    0.429
# 24    0.400
# 25    0.200
# 26    0.400
# 27    0.000
# 28    0.429
# 29    0.000
# 30    0.143
# 31    0.556
# 32    0.143
# 33    0.000
# 34    0.400
# 35    0.538
# 36    0.091
# 37    0.143
# 38    0.364
# 39    0.400
# 40    0.455
# 41    0.500
# 42    0.429
# 43    0.200
# 44    0.167
# 45    0.500
# 46    0.333
# 47    0.333
# Name: FG3_PCT, dtype: float64

# %%
ko_df['FG3_PCT'].value_counts()
# Out:
# 0.000    8
# 0.500    6
# 0.429    4
# 0.250    4
# 0.400    4
# 0.143    3
# 0.167    3
# 0.200    2
# 0.333    2
# 0.375    2
# 0.300    2
# 0.444    1
# 0.571    1
# 0.556    1
# 0.538    1
# 0.091    1
# 0.364    1
# 0.455    1
# 0.385    1
# Name: FG3_PCT, dtype: int64

# %%
ko_df['FG3_PCT'].count()
# Out:
# 48

# %%
first_five = ko_df['FG3_PCT'].value_counts().head(5)

# %%
sns.lineplot(x=(ko_df.index+1), y='FG3_PCT', data=ko_df)
# Out:
# <AxesSubplot: ylabel='FG3_PCT'>

# %%
# define moving average window
window_size = 6

# calculate MA using pandas.rolling().mean method
rolling_mean = ko_df['FG3_PCT'].rolling(window_size).mean()

# plot daily average of 3P%
sns.lineplot(x=(ko_df.index+1), y='FG3_PCT', data=ko_df)

# plot moving average of 3P%
sns.lineplot(x=(ko_df.index+1), y=rolling_mean)

#show plot
plt.show()

# %%
ko_jp = sns.jointplot(x=(ko_df.index+1), y='FG3_PCT', data=ko_df, kind='reg', marginal_kws=dict(bins=15),)
ko_jp.ax_marg_x.remove()
plt.show()

# %% [markdown]
# ## Free throw progress

# %%
# calculate all daily 3PT% of 2022-23 season
# list to hold daily 3PT% averages
daily_ftP = []
# iterate through each game of season to collect 3PA and 3PM using unique date values in 'dates' series
# calculate the daily 3P% and append to global list
for d in dates.unique():
    daily_ftM = multi_df.loc[d]['freeThrowsMade'].sum()
    daily_ftA = multi_df.loc[d]['freeThrowsAttempted'].sum()
    daily_ftP.append(daily_ftM/daily_ftA)
    
daily_ftp_df = pd.DataFrame(daily_ftP)
# modifying name of columnS
daily_ftp_df = daily_ftp_df.rename(columns={0: 'Daily FTP'})

jp = sns.jointplot(x=range(1,164), y='Daily FTP', data=daily_ftp_df[daily_ftp_df['Daily FTP'] != daily_ftp_df['Daily FTP'].min()], kind='reg')
jp.ax_marg_x.remove()
plt.show()

# %%
# define moving average window
window_size = 7

# calculate MA using pandas.rolling().mean method
rolling_mean = pd.Series(daily_ftP).rolling(window_size).mean()

# plot daily average of 3P%
sns.lineplot(x=dates.unique(), y=daily_ftP)

# plot moving average of 3P%
sns.lineplot(x=dates.unique(), y=rolling_mean)

#show plot
plt.show()
